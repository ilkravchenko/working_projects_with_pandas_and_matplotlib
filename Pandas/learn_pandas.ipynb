# %%
import pandas as pd

# %%
df = pd.read_csv('file.csv')
df
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        295665          Macbook Pro Laptop                 1     1700.00
# 1        295666          LG Washing Machine                 1      600.00
# 2        295667        USB-C Charging Cable                 1       11.95
# 3        295668            27in FHD Monitor                 1      149.99
# 4        295669        USB-C Charging Cable                 1       11.95
# ...         ...                         ...               ...         ...
# 24984    319666    Lightning Charging Cable                 1       14.95
# 24985    319667       AA Batteries (4-pack)                 2        3.84
# 24986    319668             Vareebadd Phone                 1      400.00
# 24987    319669            Wired Headphones                 1       11.99
# 24988    319670  Bose SoundSport Headphones                 1       99.99
#
#            Order Date                        Purchase Address
# ...

# %%
df.head()
# Out:
#    Order ID               Product  Quantity Ordered  Price Each  \
# 0    295665    Macbook Pro Laptop                 1     1700.00
# 1    295666    LG Washing Machine                 1      600.00
# 2    295667  USB-C Charging Cable                 1       11.95
# 3    295668      27in FHD Monitor                 1      149.99
# 4    295669  USB-C Charging Cable                 1       11.95
#
#        Order Date                        Purchase Address
# 0  12/30/19 00:01  136 Church St, New York City, NY 10001
# 1  12/29/19 07:03     562 2nd St, New York City, NY 10001
# 2  12/12/19 18:21    277 Main St, New York City, NY 10001
# 3  12/22/19 15:13     410 6th St, San Francisco, CA 94016
# 4  12/18/19 12:38           43 Hill St, Atlanta, GA 30301

# %%
df.tail()
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 24984    319666    Lightning Charging Cable                 1       14.95
# 24985    319667       AA Batteries (4-pack)                 2        3.84
# 24986    319668             Vareebadd Phone                 1      400.00
# 24987    319669            Wired Headphones                 1       11.99
# 24988    319670  Bose SoundSport Headphones                 1       99.99
#
#            Order Date                        Purchase Address
# 24984  12/11/19 20:58  14 Madison St, San Francisco, CA 94016
# 24985  12/01/19 12:01    549 Willow St, Los Angeles, CA 90001
# 24986  12/09/19 06:43        273 Wilson St, Seattle, WA 98101
# 24987  12/03/19 10:39          778 River St, Dallas, TX 75001
# 24988  12/21/19 21:45  747 Chestnut St, Los Angeles, CA 90001

# %%
df.head(10)
# Out:
#    Order ID                     Product  Quantity Ordered  Price Each  \
# 0    295665          Macbook Pro Laptop                 1     1700.00
# 1    295666          LG Washing Machine                 1      600.00
# 2    295667        USB-C Charging Cable                 1       11.95
# 3    295668            27in FHD Monitor                 1      149.99
# 4    295669        USB-C Charging Cable                 1       11.95
# 5    295670       AA Batteries (4-pack)                 1        3.84
# 6    295671        USB-C Charging Cable                 1       11.95
# 7    295672        USB-C Charging Cable                 2       11.95
# 8    295673  Bose SoundSport Headphones                 1       99.99
# 9    295674      AAA Batteries (4-pack)                 4        2.99
#
#        Order Date                           Purchase Address
# 0  12/30/19 00:01     136 Church St, New York City, NY 10001
# 1  12/29/19 07:03        562 2nd St, New York City, NY 10001
# ...

# %%
df['Purchase Address']
# Out:
# 0        136 Church St, New York City, NY 10001
# 1           562 2nd St, New York City, NY 10001
# 2          277 Main St, New York City, NY 10001
# 3           410 6th St, San Francisco, CA 94016
# 4                 43 Hill St, Atlanta, GA 30301
#                           ...
# 24984    14 Madison St, San Francisco, CA 94016
# 24985      549 Willow St, Los Angeles, CA 90001
# 24986          273 Wilson St, Seattle, WA 98101
# 24987            778 River St, Dallas, TX 75001
# 24988    747 Chestnut St, Los Angeles, CA 90001
# Name: Purchase Address, Length: 24989, dtype: object

# %%
df[['Quantity Ordered', 'Price Each', 'Order Date']]
# Out:
#        Quantity Ordered  Price Each      Order Date
# 0                     1     1700.00  12/30/19 00:01
# 1                     1      600.00  12/29/19 07:03
# 2                     1       11.95  12/12/19 18:21
# 3                     1      149.99  12/22/19 15:13
# 4                     1       11.95  12/18/19 12:38
# ...                 ...         ...             ...
# 24984                 1       14.95  12/11/19 20:58
# 24985                 2        3.84  12/01/19 12:01
# 24986                 1      400.00  12/09/19 06:43
# 24987                 1       11.99  12/03/19 10:39
# 24988                 1       99.99  12/21/19 21:45
#
# [24989 rows x 3 columns]

# %%
df['Total'] = df['Price Each'] * df['Quantity Ordered']

# %%
df
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        295665          Macbook Pro Laptop                 1     1700.00
# 1        295666          LG Washing Machine                 1      600.00
# 2        295667        USB-C Charging Cable                 1       11.95
# 3        295668            27in FHD Monitor                 1      149.99
# 4        295669        USB-C Charging Cable                 1       11.95
# ...         ...                         ...               ...         ...
# 24984    319666    Lightning Charging Cable                 1       14.95
# 24985    319667       AA Batteries (4-pack)                 2        3.84
# 24986    319668             Vareebadd Phone                 1      400.00
# 24987    319669            Wired Headphones                 1       11.99
# 24988    319670  Bose SoundSport Headphones                 1       99.99
#
#            Order Date                        Purchase Address    Total
# ...

# %%
df.rename(columns={
    'Order ID':'Order_id',
    'Quantity Ordered':'Quantity',
    'Price Each':'Price',
    'Order Date':'Order_date',
    'Purchase Address':'Purchase_address'
}, inplace=True)

# %%
df
# Out:
#        Order_id                     Product  Quantity    Price  \
# 0        295665          Macbook Pro Laptop         1  1700.00
# 1        295666          LG Washing Machine         1   600.00
# 2        295667        USB-C Charging Cable         1    11.95
# 3        295668            27in FHD Monitor         1   149.99
# 4        295669        USB-C Charging Cable         1    11.95
# ...         ...                         ...       ...      ...
# 24984    319666    Lightning Charging Cable         1    14.95
# 24985    319667       AA Batteries (4-pack)         2     3.84
# 24986    319668             Vareebadd Phone         1   400.00
# 24987    319669            Wired Headphones         1    11.99
# 24988    319670  Bose SoundSport Headphones         1    99.99
#
#            Order_date                        Purchase_address    Total
# 0      12/30/19 00:01  136 Church St, New York City, NY 10001  1700.00
# ...
