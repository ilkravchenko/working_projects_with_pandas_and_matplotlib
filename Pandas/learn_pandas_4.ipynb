# %%
import pandas as pd

# %%
df = pd.read_csv('changed_file.csv')

# %%
df
# Out:
#        Order_id                     Product  Quantity    Price  \
# 0        295665          Macbook Pro Laptop         1  1700.00
# 1        295666          LG Washing Machine         1   600.00
# 2        295667        USB-C Charging Cable         1    11.95
# 3        295668            27in FHD Monitor         1   149.99
# 4        295669        USB-C Charging Cable         1    11.95
# ...         ...                         ...       ...      ...
# 24984    319666    Lightning Charging Cable         1    14.95
# 24985    319667       AA Batteries (4-pack)         2     3.84
# 24986    319668             Vareebadd Phone         1   400.00
# 24987    319669            Wired Headphones         1    11.99
# 24988    319670  Bose SoundSport Headphones         1    99.99
#
#            Ordar_date                        Purchase_address    Total
# 0      12/30/19 00:01  136 Church St, New York City, NY 10001  1700.00
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24989 entries, 0 to 24988
# Data columns (total 7 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   Order_id          24989 non-null  int64
#  1   Product           24989 non-null  object
#  2   Quantity          24989 non-null  int64
#  3   Price             24989 non-null  float64
#  4   Ordar_date        24989 non-null  object
#  5   Purchase_address  24989 non-null  object
#  6   Total             24989 non-null  float64
# dtypes: float64(2), int64(2), object(3)
# memory usage: 1.3+ MB

# %%
df["Ordar_date"] = pd.to_datetime(df.Ordar_date, format='%m/%d/%y %H:%M')

# %%
df
# Out:
#        Order_id                     Product  Quantity    Price  \
# 0        295665          Macbook Pro Laptop         1  1700.00
# 1        295666          LG Washing Machine         1   600.00
# 2        295667        USB-C Charging Cable         1    11.95
# 3        295668            27in FHD Monitor         1   149.99
# 4        295669        USB-C Charging Cable         1    11.95
# ...         ...                         ...       ...      ...
# 24984    319666    Lightning Charging Cable         1    14.95
# 24985    319667       AA Batteries (4-pack)         2     3.84
# 24986    319668             Vareebadd Phone         1   400.00
# 24987    319669            Wired Headphones         1    11.99
# 24988    319670  Bose SoundSport Headphones         1    99.99
#
#                Ordar_date                        Purchase_address    Total
# 0     2019-12-30 00:01:00  136 Church St, New York City, NY 10001  1700.00
# ...

# %%
df.Ordar_date.dt.year
# Out:
# 0        2019
# 1        2019
# 2        2019
# 3        2019
# 4        2019
#          ...
# 24984    2019
# 24985    2019
# 24986    2019
# 24987    2019
# 24988    2019
# Name: Ordar_date, Length: 24989, dtype: int64

# %%
df.Ordar_date.dt.day_name
# Out:
# <bound method PandasDelegate._add_delegate_accessors.<locals>._create_delegator_method.<locals>.f of <pandas.core.indexes.accessors.DatetimeProperties object at 0x000001EC7A834F70>>

# %%
df.Ordar_date.dt.day_name()
# Out:
# 0           Monday
# 1           Sunday
# 2         Thursday
# 3           Sunday
# 4        Wednesday
#            ...
# 24984    Wednesday
# 24985       Sunday
# 24986       Monday
# 24987      Tuesday
# 24988     Saturday
# Name: Ordar_date, Length: 24989, dtype: object

# %%
df['Day_name'] = df.Ordar_date.dt.day_name()

# %%
df
# Out:
#        Order_id                     Product  Quantity    Price  \
# 0        295665          Macbook Pro Laptop         1  1700.00
# 1        295666          LG Washing Machine         1   600.00
# 2        295667        USB-C Charging Cable         1    11.95
# 3        295668            27in FHD Monitor         1   149.99
# 4        295669        USB-C Charging Cable         1    11.95
# ...         ...                         ...       ...      ...
# 24984    319666    Lightning Charging Cable         1    14.95
# 24985    319667       AA Batteries (4-pack)         2     3.84
# 24986    319668             Vareebadd Phone         1   400.00
# 24987    319669            Wired Headphones         1    11.99
# 24988    319670  Bose SoundSport Headphones         1    99.99
#
#                Ordar_date                        Purchase_address    Total  \
# 0     2019-12-30 00:01:00  136 Church St, New York City, NY 10001  1700.00
# ...

# %%
df.groupby('Day_name')

# %%
res = df.groupby('Day_name').agg(['sum', 'count'])['Total']
res
# Out:
# C:\Users\Админ\AppData\Local\Temp\ipykernel_5788\3552983680.py:1: FutureWarning: ['Ordar_date'] did not aggregate successfully. If any error is raised this will raise in a future version of pandas. Drop these columns/ops to avoid this warning.
#   res = df.groupby('Day_name').agg(['sum', 'count'])['Total']
#                  sum  count
# Day_name
# Friday     592051.96   3260
# Monday     763665.71   4074
# Saturday   570409.90   3173
# Sunday     735507.18   3985
# Thursday   581919.14   3243
# Tuesday    747111.03   4014
# Wednesday  628632.20   3240

# %%
import matplotlib.pyplot as plt

# %%
plt.bar(res.index, res['count'])
# Out:
# <BarContainer object of 7 artists>

# %%
plt.bar(res.index, res['sum'])
# Out:
# <BarContainer object of 7 artists>
