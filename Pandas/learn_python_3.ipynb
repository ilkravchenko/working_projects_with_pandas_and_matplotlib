# %%
import pandas as pd

# %%
df = pd.read_csv('changed_file.csv')

# %%
df
# Out:
#        Order_id                     Product  Quantity    Price  \
# 0        295665          Macbook Pro Laptop         1  1700.00
# 1        295666          LG Washing Machine         1   600.00
# 2        295667        USB-C Charging Cable         1    11.95
# 3        295668            27in FHD Monitor         1   149.99
# 4        295669        USB-C Charging Cable         1    11.95
# ...         ...                         ...       ...      ...
# 24984    319666    Lightning Charging Cable         1    14.95
# 24985    319667       AA Batteries (4-pack)         2     3.84
# 24986    319668             Vareebadd Phone         1   400.00
# 24987    319669            Wired Headphones         1    11.99
# 24988    319670  Bose SoundSport Headphones         1    99.99
#
#            Ordar_date                        Purchase_address    Total
# 0      12/30/19 00:01  136 Church St, New York City, NY 10001  1700.00
# ...

# %%
df.shape
# Out:
# (24989, 7)

# %%
import os
os.mkdir('parts')
num = 1
for i in range(0, df.shape[0], 5000):
    tmp = df.loc[i:i+5000-1]
    tmp.to_csv(f'parts/part_{num}.csv', index=False)
    num = num + 1

# %%
df.loc[1]#вывести строку
# Out:
# Order_id                                         295666
# Product                              LG Washing Machine
# Quantity                                              1
# Price                                             600.0
# Ordar_date                               12/29/19 07:03
# Purchase_address    562 2nd St, New York City, NY 10001
# Total                                             600.0
# Name: 1, dtype: object

# %%
df.loc[0:3]
# Out:
#    Order_id               Product  Quantity    Price      Ordar_date  \
# 0    295665    Macbook Pro Laptop         1  1700.00  12/30/19 00:01
# 1    295666    LG Washing Machine         1   600.00  12/29/19 07:03
# 2    295667  USB-C Charging Cable         1    11.95  12/12/19 18:21
# 3    295668      27in FHD Monitor         1   149.99  12/22/19 15:13
#
#                          Purchase_address    Total
# 0  136 Church St, New York City, NY 10001  1700.00
# 1     562 2nd St, New York City, NY 10001   600.00
# 2    277 Main St, New York City, NY 10001    11.95
# 3     410 6th St, San Francisco, CA 94016   149.99

# %%
df_all = pd.DataFrame()
for f in os.listdir('parts/'):
#     print(f)
    tmp = pd.read_csv('parts/' + f)
    df_all = pd.concat([df_all, tmp])
    
df_all
# Out:
#       Order_id                     Product  Quantity    Price      Ordar_date  \
# 0       295665          Macbook Pro Laptop         1  1700.00  12/30/19 00:01
# 1       295666          LG Washing Machine         1   600.00  12/29/19 07:03
# 2       295667        USB-C Charging Cable         1    11.95  12/12/19 18:21
# 3       295668            27in FHD Monitor         1   149.99  12/22/19 15:13
# 4       295669        USB-C Charging Cable         1    11.95  12/18/19 12:38
# ...        ...                         ...       ...      ...             ...
# 4984    319666    Lightning Charging Cable         1    14.95  12/11/19 20:58
# 4985    319667       AA Batteries (4-pack)         2     3.84  12/01/19 12:01
# 4986    319668             Vareebadd Phone         1   400.00  12/09/19 06:43
# 4987    319669            Wired Headphones         1    11.99  12/03/19 10:39
# 4988    319670  Bose SoundSport Headphones         1    99.99  12/21/19 21:45
#
# ...

# %%
df_all.reset_index(inplace=True, drop=True)
df_all
# Out:
#        Order_id                     Product  Quantity    Price  \
# 0        295665          Macbook Pro Laptop         1  1700.00
# 1        295666          LG Washing Machine         1   600.00
# 2        295667        USB-C Charging Cable         1    11.95
# 3        295668            27in FHD Monitor         1   149.99
# 4        295669        USB-C Charging Cable         1    11.95
# ...         ...                         ...       ...      ...
# 24984    319666    Lightning Charging Cable         1    14.95
# 24985    319667       AA Batteries (4-pack)         2     3.84
# 24986    319668             Vareebadd Phone         1   400.00
# 24987    319669            Wired Headphones         1    11.99
# 24988    319670  Bose SoundSport Headphones         1    99.99
#
#            Ordar_date                        Purchase_address    Total
# 0      12/30/19 00:01  136 Church St, New York City, NY 10001  1700.00
# ...
