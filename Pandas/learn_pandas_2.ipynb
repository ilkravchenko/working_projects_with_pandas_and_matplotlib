# %%
import pandas as pd

# %%
df = pd.read_csv('file.csv')
df
# Out:
#        Order ID                     Product  Quantity Ordered  Price Each  \
# 0        295665          Macbook Pro Laptop                 1     1700.00
# 1        295666          LG Washing Machine                 1      600.00
# 2        295667        USB-C Charging Cable                 1       11.95
# 3        295668            27in FHD Monitor                 1      149.99
# 4        295669        USB-C Charging Cable                 1       11.95
# ...         ...                         ...               ...         ...
# 24984    319666    Lightning Charging Cable                 1       14.95
# 24985    319667       AA Batteries (4-pack)                 2        3.84
# 24986    319668             Vareebadd Phone                 1      400.00
# 24987    319669            Wired Headphones                 1       11.99
# 24988    319670  Bose SoundSport Headphones                 1       99.99
#
#            Order Date                        Purchase Address
# ...

# %%
df['Total'] = df['Quantity Ordered'] * df['Price Each']

# %%
df.rename(columns={
    'Order ID':'Order_id',
    'Quantity Ordered':'Quantity',
    'Price Each': 'Price',
    'Order Date': 'Ordar_date',
    'Purchase Address':'Purchase_address'
})
# Out:
#        Order_id                     Product  Quantity    Price  \
# 0        295665          Macbook Pro Laptop         1  1700.00
# 1        295666          LG Washing Machine         1   600.00
# 2        295667        USB-C Charging Cable         1    11.95
# 3        295668            27in FHD Monitor         1   149.99
# 4        295669        USB-C Charging Cable         1    11.95
# ...         ...                         ...       ...      ...
# 24984    319666    Lightning Charging Cable         1    14.95
# 24985    319667       AA Batteries (4-pack)         2     3.84
# 24986    319668             Vareebadd Phone         1   400.00
# 24987    319669            Wired Headphones         1    11.99
# 24988    319670  Bose SoundSport Headphones         1    99.99
#
#            Ordar_date                        Purchase_address    Total
# 0      12/30/19 00:01  136 Church St, New York City, NY 10001  1700.00
# ...

# %%
df = df.rename(columns={
    'Order ID':'Order_id',
    'Quantity Ordered':'Quantity',
    'Price Each': 'Price',
    'Order Date': 'Ordar_date',
    'Purchase Address':'Purchase_address'
})

# %%
df
# Out:
#        Order_id                     Product  Quantity    Price  \
# 0        295665          Macbook Pro Laptop         1  1700.00
# 1        295666          LG Washing Machine         1   600.00
# 2        295667        USB-C Charging Cable         1    11.95
# 3        295668            27in FHD Monitor         1   149.99
# 4        295669        USB-C Charging Cable         1    11.95
# ...         ...                         ...       ...      ...
# 24984    319666    Lightning Charging Cable         1    14.95
# 24985    319667       AA Batteries (4-pack)         2     3.84
# 24986    319668             Vareebadd Phone         1   400.00
# 24987    319669            Wired Headphones         1    11.99
# 24988    319670  Bose SoundSport Headphones         1    99.99
#
#            Ordar_date                        Purchase_address    Total
# 0      12/30/19 00:01  136 Church St, New York City, NY 10001  1700.00
# ...

# %%
df.rename(columns={
    'Order ID':'Order_id',
    'Quantity Ordered':'Quantity',
    'Price Each': 'Price',
    'Order Date': 'Ordar_date',
    'Purchase Address':'Purchase_address'
}, inplace=True)

# %%
df
# Out:
#        Order_id                     Product  Quantity    Price  \
# 0        295665          Macbook Pro Laptop         1  1700.00
# 1        295666          LG Washing Machine         1   600.00
# 2        295667        USB-C Charging Cable         1    11.95
# 3        295668            27in FHD Monitor         1   149.99
# 4        295669        USB-C Charging Cable         1    11.95
# ...         ...                         ...       ...      ...
# 24984    319666    Lightning Charging Cable         1    14.95
# 24985    319667       AA Batteries (4-pack)         2     3.84
# 24986    319668             Vareebadd Phone         1   400.00
# 24987    319669            Wired Headphones         1    11.99
# 24988    319670  Bose SoundSport Headphones         1    99.99
#
#            Ordar_date                        Purchase_address    Total
# 0      12/30/19 00:01  136 Church St, New York City, NY 10001  1700.00
# ...

# %%
df.to_csv('changed_file.csv', index=False)

# %%
df[ df.Price > 1000 ]
# Out:
#        Order_id             Product  Quantity   Price      Ordar_date  \
# 0        295665  Macbook Pro Laptop         1  1700.0  12/30/19 00:01
# 52       295712  Macbook Pro Laptop         1  1700.0  12/10/19 20:02
# 57       295717  Macbook Pro Laptop         1  1700.0  12/25/19 09:51
# 223      295871  Macbook Pro Laptop         1  1700.0  12/28/19 11:19
# 302      295948  Macbook Pro Laptop         1  1700.0  12/17/19 21:08
# ...         ...                 ...       ...     ...             ...
# 24885    319570  Macbook Pro Laptop         1  1700.0  12/09/19 17:40
# 24924    319607  Macbook Pro Laptop         1  1700.0  12/25/19 20:07
# 24939    319622  Macbook Pro Laptop         1  1700.0  12/15/19 07:11
# 24957    319639  Macbook Pro Laptop         1  1700.0  12/20/19 10:56
# 24959    319641  Macbook Pro Laptop         1  1700.0  12/04/19 23:11
#
#                               Purchase_address   Total
# 0       136 Church St, New York City, NY 10001  1700.0
# ...

# %%
df[ df.Product.str.contains('LG') ]
# Out:
#        Order_id             Product  Quantity  Price      Ordar_date  \
# 1        295666  LG Washing Machine         1  600.0  12/29/19 07:03
# 27       295689  LG Washing Machine         1  600.0  12/24/19 11:21
# 694      296329  LG Washing Machine         1  600.0  12/01/19 11:49
# 745      296376            LG Dryer         1  600.0  12/21/19 10:10
# 845      296472            LG Dryer         1  600.0  12/21/19 10:50
# ...         ...                 ...       ...    ...             ...
# 24319    319023            LG Dryer         1  600.0  12/24/19 17:38
# 24332    319035            LG Dryer         1  600.0  12/17/19 23:55
# 24674    319364  LG Washing Machine         1  600.0  12/03/19 19:35
# 24904    319588            LG Dryer         1  600.0  12/21/19 12:49
# 24975    319657            LG Dryer         1  600.0  12/05/19 13:22
#
#                               Purchase_address  Total
# 1          562 2nd St, New York City, NY 10001  600.0
# ...

# %%
df[ ~df.Product.str.contains('LG') ]
# Out:
#        Order_id                     Product  Quantity    Price  \
# 0        295665          Macbook Pro Laptop         1  1700.00
# 2        295667        USB-C Charging Cable         1    11.95
# 3        295668            27in FHD Monitor         1   149.99
# 4        295669        USB-C Charging Cable         1    11.95
# 5        295670       AA Batteries (4-pack)         1     3.84
# ...         ...                         ...       ...      ...
# 24984    319666    Lightning Charging Cable         1    14.95
# 24985    319667       AA Batteries (4-pack)         2     3.84
# 24986    319668             Vareebadd Phone         1   400.00
# 24987    319669            Wired Headphones         1    11.99
# 24988    319670  Bose SoundSport Headphones         1    99.99
#
#            Ordar_date                           Purchase_address    Total
# 0      12/30/19 00:01     136 Church St, New York City, NY 10001  1700.00
# ...

# %%
df[ (df.Product.str.contains('LG')) & (df.Price < 600) ]
# Out:
# Empty DataFrame
# Columns: [Order_id, Product, Quantity, Price, Ordar_date, Purchase_address, Total]
# Index: []

# %%
df[ (df.Product.str.contains('Batteries')) & (df.Total > 5) ]
# Out:
#        Order_id                 Product  Quantity  Price      Ordar_date  \
# 9        295674  AAA Batteries (4-pack)         4   2.99  12/28/19 11:51
# 12       295677   AA Batteries (4-pack)         2   3.84  12/20/19 19:19
# 13       295678  AAA Batteries (4-pack)         2   2.99  12/06/19 09:38
# 22       295684  AAA Batteries (4-pack)         4   2.99  12/04/19 12:29
# 30       295692   AA Batteries (4-pack)         2   3.84  12/14/19 01:21
# ...         ...                     ...       ...    ...             ...
# 24941    319624   AA Batteries (4-pack)         2   3.84  12/30/19 12:15
# 24961    319643   AA Batteries (4-pack)         2   3.84  12/25/19 12:38
# 24965    319647   AA Batteries (4-pack)         2   3.84  12/28/19 17:43
# 24976    319658  AAA Batteries (4-pack)         2   2.99  12/24/19 20:46
# 24985    319667   AA Batteries (4-pack)         2   3.84  12/01/19 12:01
#
#                               Purchase_address  Total
# ...
